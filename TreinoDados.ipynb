# %%
import pandas as pd

# %%
dados = pd.read_csv('../Dados/DADOS/tempo.csv', sep=';')
dados.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70      NaN       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
dados.shape
# Out:
# (14, 5)

# %%
aparencia = dados.groupby(['Aparencia']).size()
aparencia
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
dados.loc[dados['Aparencia'] == 'menos', 'Aparencia'] = 'sol'

aparencia = dados.groupby(['Aparencia']).size()
aparencia
# Out:
# Aparencia
# chuva      5
# nublado    3
# sol        6
# dtype: int64

# %%
aparencia.plot.bar(color='purple')
# Out:
# <AxesSubplot:xlabel='Aparencia'>

# %%
# TRATAR NO FINAL
dados.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        0
# Vento          0
# Jogar          0
# dtype: int64

# %%
dados['Umidade'].fillna(85, inplace=True)

# %%
dados['Vento'].fillna('falso', inplace=True)

# %%
dados.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70      NaN       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
temperatura = dados.groupby(['Temperatura']).size()
temperatura
# Out:
# Temperatura
# 64      1
# 65      1
# 68      1
# 69      1
# 70      1
# 71      1
# 72      1
# 75      2
# 80      1
# 81      1
# 83      1
# 85      1
# 1220    1
# dtype: int64

# %%
dados['Temperatura'].describe()
# Out:
# count    14.000000
# mean     73.642857
# std       6.558695
# min      64.000000
# 25%      69.250000
# 50%      72.500000
# 75%      78.750000
# max      85.000000
# Name: Temperatura, dtype: float64

# %%
dados.loc[(dados['Temperatura'] == 1220), 'Temperatura'] = 73

# %%
dados.loc[(dados['Temperatura'] == 1220)]
# Out:
# Empty DataFrame
# Columns: [Aparencia, Temperatura, Umidade, Vento, Jogar]
# Index: []

# %%
temperatura.plot.bar(color='green')
# Out:
# <AxesSubplot:xlabel='Temperatura'>

# %%
umidade = dados.groupby(['Umidade']).size()
umidade
# Out:
# Umidade
# 65.0     1
# 70.0     3
# 75.0     1
# 80.0     1
# 85.0     1
# 86.0     1
# 90.0     2
# 91.0     1
# 95.0     1
# 200.0    1
# dtype: int64

# %%
dados['Umidade'].describe()
# Out:
# count    13.000000
# mean     80.923077
# std       9.878103
# min      65.000000
# 25%      70.000000
# 50%      85.000000
# 75%      90.000000
# max      95.000000
# Name: Umidade, dtype: float64

# %%
dados.loc[(dados['Umidade'] == 200), 'Umidade'] = 85

# %%
umidade.plot.bar(color='blue')
# Out:
# <AxesSubplot:xlabel='Umidade'>

# %%
dados.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70     85.0       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
vento = dados.groupby(['Vento']).size()
vento
# Out:
# Vento
# FALSO         7
# VERDADEIRO    6
# dtype: int64

# %%
vento.plot.bar(color='gray')
# Out:
# <AxesSubplot:xlabel='Vento'>

# %%
dados.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70     85.0       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
jogar = dados.groupby(['Jogar']).size()
jogar
# Out:
# Jogar
# nao    5
# sim    9
# dtype: int64
